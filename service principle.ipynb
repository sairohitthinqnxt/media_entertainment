# %%
application_id = dbutils.secrets.get(scope="media_scope",key="applicationId")
skey = dbutils.secrets.get(scope="media_scope",key="skey")
tenantId = dbutils.secrets.get(scope="media_scope",key="tenantId")

spark.conf.set("fs.azure.account.auth.type.babustorage01.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.babustorage01.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.babustorage01.dfs.core.windows.net", application_id)
spark.conf.set("fs.azure.account.oauth2.client.secret.babustorage01.dfs.core.windows.net", skey)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.babustorage01.dfs.core.windows.net", f"https://login.microsoftonline.com/{tenantId}/oauth2/token")

# %%
dbutils.fs.secrets.list(scope = "media_scope"
