# %%
# %sql
select * from media_lakehouse.bronze.ad_events_raw;

# %%
# %sql
select * from media_lakehouse.bronze.campaign_raw

# %%
# %sql
select * from media_lakehouse.bronze.content_raw

# %%
# %sql
select * from media_lakehouse.bronze.payment_raw

# %%
# %sql
select * from media_lakehouse.bronze.quarantine_events

# %%
# %sql
select * from media_lakehouse.bronze.social_signals_raw

# %%
# %sql
select * from media_lakehouse.bronze.subscription_raw

# %%
# %sql
select * from media_lakehouse.bronze.user_events_raw

# %%
# %sql
select * from media_lakehouse.bronze.user_profile_raw
