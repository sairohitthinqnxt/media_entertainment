# %%
# %sql
select * from media_lakehouse.silver.dim_campaign

# %%
# %sql
select * from media_lakehouse.silver.dim_content

# %%
# %sql
select * from media_lakehouse.silver.dim_device

# %%
# %sql
select * from media_lakehouse.silver.dim_geo

# %%
# %sql
select * from media_lakehouse.silver.dim_platform

# %%
# %sql
select * from media_lakehouse.silver.dim_subscription

# %%
# %sql
select * from media_lakehouse.silver.dim_user

# %%
# %sql
select * from media_lakehouse.silver.dq_metrics

# %%
# %sql
select * from media_lakehouse.silver.fact_ad_events

# %%
# %sql
select * from media_lakehouse.silver.fact_payments

# %%
# %sql
select * from media_lakehouse.silver.fact_playback

# %%
# %sql
select * from media_lakehouse.silver.fact_qoe

# %%
# %sql
select * from media_lakehouse.silver.fact_search

# %%
# %sql
select * from media_lakehouse.silver.fact_sessions

# %%
# %sql
select * from media_lakehouse.silver.fact_social_signals

# %%
# %sql
select * from media_lakehouse.silver.metrics
