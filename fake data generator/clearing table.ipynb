# %%
# %sql
--clearing out the bronze tables
delete from media_lakehouse.bronze.ad_events_raw;
delete from media_lakehouse.bronze.campaign_raw;
delete from media_lakehouse.bronze.content_raw;
delete from media_lakehouse.bronze.subscription_raw;
delete from media_lakehouse.bronze.user_profile_raw;
delete from media_lakehouse.bronze.user_events_raw;
delete from media_lakehouse.bronze.quarantine_events;
delete from media_lakehouse.bronze.ad_events_raw;
delete from media_lakehouse.bronze.payment_raw;

# %%
# %sql
--clearing out the silver tables
delete from media_lakehouse.silver.dim_campaign;
delete from media_lakehouse.silver.dim_content;
delete from media_lakehouse.silver.dim_device;
delete from media_lakehouse.silver.dim_geo;
delete from media_lakehouse.silver.dim_platform;
delete from media_lakehouse.silver.dim_subscription;
delete from media_lakehouse.silver.dim_user;
delete from media_lakehouse.silver.dq_metrics;
delete from media_lakehouse.silver.fact_ad_events;
delete from media_lakehouse.silver.fact_payments;
delete from media_lakehouse.silver.fact_playback;
delete from media_lakehouse.silver.fact_qoe;
delete from media_lakehouse.silver.fact_search;
delete from media_lakehouse.silver.fact_sessions;
delete from media_lakehouse.silver.fact_social_signals;
delete from media_lakehouse.silver.metrics;

# %%
# %sql
--clearing gold tables
delete from media_lakehouse.gold.ad_daily_yield;
delete from media_lakehouse.gold.audience_daily_engagement;
delete from media_lakehouse.gold.content_daily_kpis;
delete from media_lakehouse.gold.discovery_daily;
delete from media_lakehouse.gold.qoe_daily_summary;
delete from media_lakehouse.gold.subscription_daily_summary

# %%
# %sql
select * from media_lakehouse.silver.dim_geo
