# %%
# %run "/Workspace/Users/gowtham.thinqnxt@gmail.com/media_entertainment/service principle"

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from src.common.config1 import CatalogConfig
from src.common.config2 import StorageConfig

from src.ingestion.bronze_ingestion import ingest_rawpay

spark=SparkSession.builder.getOrCreate()

c=CatalogConfig()

s=StorageConfig()

# %%
social_schema = StructType([
  StructField("signal_id", StringType()),
  StructField("platform", StringType()),
  StructField("content_id", StringType()),
  StructField("mention_ts", TimestampType()),
  StructField("sentiment", DoubleType()),
  StructField("mentions", IntegerType()),
  StructField("engagement", IntegerType())
])

# %%
ingest_rawpay(spark, "abfss://source@babustorage01.dfs.core.windows.net/media_lakehouse/social_signals_raw", "parquet", social_schema, c.t(c.bronze, "social_signals_raw"))
