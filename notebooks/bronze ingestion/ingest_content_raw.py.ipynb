# %%
# %run "/Workspace/Users/gowtham.thinqnxt@gmail.com/media_entertainment/service principle"

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from src.common.config1 import CatalogConfig
from src.common.config2 import StorageConfig

from src.ingestion.bronze_ingestion import ingest

spark=SparkSession.builder.getOrCreate()

c=CatalogConfig()

s=StorageConfig()

# %%
content_schema = StructType([
  StructField("content_id", StringType()),
  StructField("title", StringType()),
  StructField("content_type", StringType()),
  StructField("genre", StringType()),
  StructField("language", StringType()),
  StructField("release_date", DateType()),
  StructField("duration_sec", LongType()),
  StructField("publisher", StringType()),
  StructField("tags", ArrayType(StringType())),
  StructField("last_updated", TimestampType()),
])

# %%
ingest(spark, "abfss://source@babustorage01.dfs.core.windows.net/media_lakehouse/content_raw", "parquet", content_schema, c.t(c.bronze, "content_raw"))
